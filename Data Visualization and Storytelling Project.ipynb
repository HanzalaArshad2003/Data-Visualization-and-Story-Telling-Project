# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("euro-daily-hist_1999_2020.csv")

# %%
dataset.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2021-01-08               1.5758           1.9558            6.5748
# 1   2021-01-07               1.5836           1.9558            6.5172
# 2   2021-01-06               1.5824           1.9558            6.5119
# 3   2021-01-05               1.5927           1.9558            6.5517
# 4   2021-01-04               1.5928           1.9558            6.3241
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.5543         1.0827                   7.9184              NaN
# 1             1.5601         1.0833                   7.9392              NaN
# 2             1.5640         1.0821                   7.9653              NaN
# 3             1.5651         1.0803                   7.9315              NaN
# 4             1.5621         1.0811                   7.9484              NaN
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              5699 non-null   object
#  1   [Australian dollar ]      5699 non-null   object
#  2   [Bulgarian lev ]          5297 non-null   object
#  3   [Brazilian real ]         5431 non-null   object
#  4   [Canadian dollar ]        5699 non-null   object
#  5   [Swiss franc ]            5699 non-null   object
#  6   [Chinese yuan renminbi ]  5431 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           5699 non-null   object
#  9   [Danish krone ]           5699 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      5699 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %%
dataset.rename(columns={'Period\\Unit:':'Time'},inplace=True)#Backslash two times BCZ of some reason

# %%
dataset.rename(columns={'[US dollar ]':'USD'},inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Time                      5699 non-null   object
#  1   [Australian dollar ]      5699 non-null   object
#  2   [Bulgarian lev ]          5297 non-null   object
#  3   [Brazilian real ]         5431 non-null   object
#  4   [Canadian dollar ]        5699 non-null   object
#  5   [Swiss franc ]            5699 non-null   object
#  6   [Chinese yuan renminbi ]  5431 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           5699 non-null   object
#  9   [Danish krone ]           5699 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      5699 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %%
dataset.Time=pd.to_datetime(dataset.Time)

# %%
dataset.sort_values("Time",inplace=True)

# %%
dataset.reset_index(inplace=True,drop=True)

# %%
dataset.head()
# Out:
#         Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0 1999-01-04               1.9100              NaN               NaN
# 1 1999-01-05               1.8944              NaN               NaN
# 2 1999-01-06               1.8820              NaN               NaN
# 3 1999-01-07               1.8474              NaN               NaN
# 4 1999-01-08               1.8406              NaN               NaN
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.8004         1.6168                      NaN          0.58231
# 1             1.7965         1.6123                      NaN          0.58230
# 2             1.7711         1.6116                      NaN          0.58200
# 3             1.7602         1.6165                      NaN          0.58187
# 4             1.7643         1.6138                      NaN          0.58187
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# ...

# %%
euro_to_dollar=dataset[["Time","USD"]].copy()

# %%
euro_to_dollar
# Out:
#            Time     USD
# 0    1999-01-04  1.1789
# 1    1999-01-05  1.1790
# 2    1999-01-06  1.1743
# 3    1999-01-07  1.1632
# 4    1999-01-08  1.1659
# ...         ...     ...
# 5694 2021-01-04  1.2296
# 5695 2021-01-05  1.2271
# 5696 2021-01-06  1.2338
# 5697 2021-01-07  1.2276
# 5698 2021-01-08  1.2250
#
# [5699 rows x 2 columns]

# %%
euro_to_dollar["USD"].value_counts()
# Out:
# USD
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.1797     6
#           ..
# 1.2571     1
# 1.2610     1
# 1.2651     1
# 1.2632     1
# 1.2193     1
# Name: count, Length: 3528, dtype: int64

# %%
euro_to_dollar=euro_to_dollar[euro_to_dollar.USD != "-"]#To print without hyphen

# %%
euro_to_dollar["USD"].value_counts()
# Out:
# USD
# 1.2276    9
# 1.1215    8
# 1.1305    7
# 1.3373    6
# 1.3532    6
#          ..
# 1.2571    1
# 1.2610    1
# 1.2651    1
# 1.2632    1
# 1.2193    1
# Name: count, Length: 3527, dtype: int64

# %%
euro_to_dollar['USD'] = euro_to_dollar['USD'].astype(float)

# %%
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5637 entries, 0 to 5698
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5637 non-null   datetime64[ns]
#  1   USD     5637 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 132.1 KB

# %%
euro_to_dollar.head()
# Out:
#         Time     USD
# 0 1999-01-04  1.1789
# 1 1999-01-05  1.1790
# 2 1999-01-06  1.1743
# 3 1999-01-07  1.1632
# 4 1999-01-08  1.1659

# %%
plt.plot(euro_to_dollar["Time"],euro_to_dollar["USD"])
plt.show()

# %%
euro_to_dollar["USD"].rolling(7).mean().head(8)#& rolling means 1st 6 vlues mean
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6    1.167171
# 7    1.166529
# Name: USD, dtype: float64

# %%
euro_to_dollar["rolling_mean"]=euro_to_dollar["USD"].rolling(30).mean()#30 wala liya kyunke osmain details shi se bta chl rhi hein

# %%
euro_to_dollar.head(40)
# Out:
#          Time     USD  rolling_mean
# 0  1999-01-04  1.1789           NaN
# 1  1999-01-05  1.1790           NaN
# 2  1999-01-06  1.1743           NaN
# 3  1999-01-07  1.1632           NaN
# 4  1999-01-08  1.1659           NaN
# 5  1999-01-11  1.1569           NaN
# 6  1999-01-12  1.1520           NaN
# 7  1999-01-13  1.1744           NaN
# 8  1999-01-14  1.1653           NaN
# 9  1999-01-15  1.1626           NaN
# 10 1999-01-18  1.1612           NaN
# 11 1999-01-19  1.1616           NaN
# 12 1999-01-20  1.1575           NaN
# 13 1999-01-21  1.1572           NaN
# 14 1999-01-22  1.1567           NaN
# 15 1999-01-25  1.1584           NaN
# 16 1999-01-26  1.1582           NaN
# 17 1999-01-27  1.1529           NaN
# 18 1999-01-28  1.1410           NaN
# 19 1999-01-29  1.1384           NaN
# 20 1999-02-01  1.1338           NaN
# 21 1999-02-02  1.1337           NaN
# 22 1999-02-03  1.1337           NaN
# 23 1999-02-04  1.1263           NaN
# 24 1999-02-05  1.1292           NaN
# ...

# %%
Financial_Crisis=euro_to_dollar[(euro_to_dollar.Time.dt.year >= 2006) & (euro_to_dollar.Time.dt.year <= 2009)]
Financial_Crisis_7_8=euro_to_dollar[(euro_to_dollar.Time.dt.year >= 2007) & (euro_to_dollar.Time.dt.year <= 2008)]

# %%
import matplotlib.style as style
style.use("fivethirtyeight")

# %%
fig, ax=plt.subplots(figsize=(8,3))

ax.plot(Financial_Crisis.Time,Financial_Crisis["rolling_mean"],linewidth=1.5,color="green")
ax.plot(Financial_Crisis_7_8.Time,Financial_Crisis_7_8["rolling_mean"],linewidth=2,color="red")

plt.xticks(rotation=90)
plt.show()

# %%
fig, ax=plt.subplots(figsize=(8,3))

ax.plot(Financial_Crisis.Time,Financial_Crisis["rolling_mean"],linewidth=1.5,color="green")
ax.plot(Financial_Crisis_7_8.Time,Financial_Crisis_7_8["rolling_mean"],linewidth=2,color="red")

#plt.xticks(rotation=90)
ax.set_xticklabels(["2006","","2007","","2008","","2009","","2010"],alpha=0.3,fontdict={"fontsize":11})
ax.set_yticklabels(["","1.2","1.3","1.4","$ 1.5"],alpha=0.3,fontdict={"fontsize":11})

#For Text in anywhere in graph
ax.text(pd.to_datetime("2006-01-1"),1.7,"EURO-USD peaked at 1.59$ during 2008-2009",weight="bold")
ax.text(pd.to_datetime("2006-01-1"),1.65,"EURO-USD between 2006 to 2010")

ax.text(pd.to_datetime("2005-5-1"),1.07,"(C) Hanzala Arshad" + " "*72 + "Source: European Central Bank",backgroundcolor="#4d4d4d")
ax.axvspan(xmin=pd.to_datetime("2008-4-1"),xmax=pd.to_datetime("2008-9-1"),color="grey",alpha=0.4,ymin=0.08)
plt.show()
